# %% [markdown]
# ![ieseg logo](./img/ieseg.png)
#
# #### MBD 2021-2022
# # Statistical & Machine Learning Approaches for Marketing
#
# ## Section 1: Introduction & Linear Regression

# %% [markdown]
# # MARIA ARQUES

# %% [markdown]
# # Excercise 2

# %%
#part a
    #scenario=regression
    #interest=inference
    #n=500
    #p=3(profit, number of employees and industry)

#part b
    #scenario=classification
    #interest=prediction
    #n=20
    #p=13

#part c
    #scenario=regression
    #interest=prediction
    #n=52
    #p=3

# %% [markdown]
# # Excercise 10

# %%
#read the data
library(MASS)
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
#number of rows and columns in the dataset
nrow(Boston)
ncol(Boston)

#rows are suburbs and columns are variables/predictors
# Out:
# [1] 506
# [1] 14

# %%
#plot some scatterplots
par(mfrow=c(2,2)) #code retrieved from https://www.statmethods.net/advgraphs/layout.html

plot(Boston$nox,Boston$crim, pch=21, cex=0.8, bg='red',xlab='NOX', ylab='Crim')
plot(Boston$age,Boston$crim, pch=21, cex=0.8, bg='green',xlab='Age', ylab='Crim')
plot(Boston$dis,Boston$crim, pch=21, cex=0.8, bg='blue',xlab='Dis', ylab='Crim')
plot(Boston$crim,Boston$medv, pch=21, cex=0.8, bg='pink',xlab='Crim', ylab='Median Value')
# Out:
# plot without title

# %%
#i decided to build a correlation matrix between all variables, we just need to look at the first column and compare it to each row
cor(Boston)

#there seems to be a positive strong correlation with RAD and Crime rate
#There seems to be a positive strong correlation with TAX and Crime rate
#there seems to be a negative relationship between MEDV and Crime rates
#there seems to be a negative relation between BLACK and Crime rates

#There may be a positive relationship between crim and rad, crime and tax
#There may be a negative relationship between crim and medv, crime and black, crime and dis
# Out:
#         crim        zn          indus       chas         nox
# crim     1.00000000 -0.20046922  0.40658341 -0.055891582  0.42097171
# zn      -0.20046922  1.00000000 -0.53382819 -0.042696719 -0.51660371
# indus    0.40658341 -0.53382819  1.00000000  0.062938027  0.76365145
# chas    -0.05589158 -0.04269672  0.06293803  1.000000000  0.09120281
# nox      0.42097171 -0.51660371  0.76365145  0.091202807  1.00000000
# rm      -0.21924670  0.31199059 -0.39167585  0.091251225 -0.30218819
# age      0.35273425 -0.56953734  0.64477851  0.086517774  0.73147010
# dis     -0.37967009  0.66440822 -0.70802699 -0.099175780 -0.76923011
# rad      0.62550515 -0.31194783  0.59512927 -0.007368241  0.61144056
# tax      0.58276431 -0.31456332  0.72076018 -0.035586518  0.66802320
# ptratio  0.28994558 -0.39167855  0.38324756 -0.121515174  0.18893268
# black   -0.38506394  0.17552032 -0.35697654  0.048788485 -0.38005064
# lstat    0.45562148 -0.41299457  0.60379972 -0.053929298  0.59087892
# ...

# %%
#part d
#suburbs with high crime rates
hist(Boston$crim, breaks = 15)
#based on the histogram we can see that approximately 10 suburbs have high crime rates, more specifically 5 suburbs have 400 crime rates 
#the other 5 suburbs have 50 crime rates
# Out:
# Plot with title "Histogram of Boston$crim"

# %%
#suburbs with high tax rates
hist(Boston$tax, breaks = 15)
# Out:
# Plot with title "Histogram of Boston$tax"

# %%
# suburbs with high pupil-teacher ratio
hist(Boston$ptratio, breaks = 15)
# Out:
# Plot with title "Histogram of Boston$ptratio"

# %%
#part e
sum(Boston$chas==1)
# Out:
# [1] 35

# %%
#part f
median(Boston$ptratio)
# Out:
# [1] 19.05

# %%
#part g
#lowest median value of owner occupied homes
min(Boston$medv)

#values of the other predictors for that suburb
predictors=(subset(Boston, medv == min(Boston$medv)))
predictors
#there is 2 suburbs that have the lowest median value of owner occuppied homes
# Out:
# [1] 5
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5

# %%
#part h
sum(Boston$rm>7)
sum(Boston$rm>8)
# Out:
# [1] 64
# [1] 13

# %% [markdown]
# # Excercise 3

# %%
#Equation for salary
 # Salary = 50 + 20 * GPA + 0.07 * IQ + 35 * Gender + 0.01 * GPA * IQ - 10 * GPA * Gender.

#i. for a fixed value of IQ and GPA, males earn more on average than females.
    #FALSE, it depends on the value of the IQ and GPA

#ii. for a fixed value of IQ and GPA, females earn more on average than males.
    #FALSE, it depends on the value of the IQ and GPA

#iii. for a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough

    #salary female= 85 + 10*GPA+ 0.07*IQ+ 0.01*GPA*IQ
    #salary male= 50 + 20*GPA+ 0.07*IQ+ 0.01*GPA*IQ

    #from this we can say that female earn 35-10*GPA more than man, so the higher the value of the GPA the less we are substraction and therefore the lowest the salary of females
    #TRUE

#iiii. for a fixed value of IQ and GPA, females earn more on average than males provided that the GPA is high enough

    #FALSE

# %%
#(b) Predict the salary of a female with IQ of 110 and a GPA of 4.0.
#salary female
#50 + 20GPA + 0.07IQ + 35 * Female(1) + 0.01(GPA * IQ) - 10GPA*Female(1)

#we replace it
salary=50 + 20 * 4 + 0.07 * 110 + 35 * 1 + 0.01 * 4 * 110 - 10 * 4
salary
# Out:
# [1] 137.1

# %%
# (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.
#false, a small interaction doesn't translate into a small interaction effect.You can have significant evidence but not effect at all.

# %% [markdown]
# # Excercise 10

# %%
#part a) Fit a multiple regression model to predict “Sales” using “Price”, “Urban” and “US”.
library(ISLR)
Carseats
# Out:
#     Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1    9.50 138        73    11          276        120   Bad       42  17
# 2   11.22 111        48    16          260         83   Good      65  10
# 3   10.06 113        35    10          269         80   Medium    59  12
# 4    7.40 117       100     4          466         97   Medium    55  14
# 5    4.15 141        64     3          340        128   Bad       38  13
# 6   10.81 124       113    13          501         72   Bad       78  16
# 7    6.63 115       105     0           45        108   Medium    71  15
# 8   11.85 136        81    15          425        120   Good      67  10
# 9    6.54 132       110     0          108        124   Medium    76  10
# 10   4.69 132       113     0          131        124   Medium    76  17
# 11   9.01 121        78     9          150        100   Bad       26  10
# 12  11.96 117        94     4          503         94   Good      50  13
# ...

# %%
#formula page 113
mreg <- lm(Sales ~ Price + Urban + US, data = Carseats)
summary(mreg)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %%
#Part b) Provide an interpretation of each coefficient in the model. Be careful - some of the variables in the model are qualitative !


# For each 1 dollar of price increase, sales decrease by 54.46 units taking into account that other predictors remain fixed.
# The sales in the urban location are 21.92 units less than in rural location taking into account that other predictors remain fixed.
# he sales in the us stores are 1200.57 units more than in non us stores taking into account that other predictors remain fixed.

# %%
#Part c) Write out the model in equation form, being careful to handle the qualitative variables properly.
# Sales=13.0434689+(−0.0544588)×Price+(−0.0219162)×Urban+(1.2005727)×US

#Urban=1 store in an urban location and 0 if not, and US=1 if store is in the US and 0 if not.

# %%
#Part d) For which of the predictors can you reject the null hypothesis H0:βj=0 ?

#We can reject the null hypothesis for the “Price” and “USYES” variables as the p-value is less than 0.05.
#Contrarily, the p-value for UrbanYes is 0.936

# %%
#Part e) On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.
mreg1 <- lm(Sales ~ Price + US, data = Carseats)
summary(mreg1)
# Out:
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %%
#Part f) How well do the models in (a) and (e) fit the data ?
#Model e is better explained than model a as the residual standard error is less

# %%
#Part g) Using the model from (e), obtain 95% confidence intervals for the coefficient(s).
confint(mreg1)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# # Excercise 15

# %%
# part a)
library(MASS)
attach(Boston)
Boston
# Out:
# The following objects are masked from Boston (pos = 3):
#
#     age, black, chas, crim, dis, indus, lstat, medv, nox, ptratio, rad,
#     rm, tax, zn
#
# The following objects are masked from Boston (pos = 4):
#
#     age, black, chas, crim, dis, indus, lstat, medv, nox, ptratio, rad,
#     rm, tax, zn
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# ...

# %%
fit.zn <- lm(crim ~ zn)
fit.indus <- lm(crim ~ indus)
fit.chas <- lm(crim ~ chas)
fit.nox <- lm(crim ~ nox)
fit.rm <- lm(crim ~ rm)
fit.age <- lm(crim ~ age)
fit.dis <- lm(crim ~ dis)
fit.rad <- lm(crim ~ rad)
fit.tax <- lm(crim ~ tax)
fit.ptratio <- lm(crim ~ ptratio)
fit.black <- lm(crim ~ black)
fit.lstat <- lm(crim ~ lstat)
fit.medv <- lm(crim ~ medv)
# Out:
# Error in model.frame.default(formula = crim ~ zn, drop.unused.levels = TRUE): invalid type (list) for variable 'zn'
# Traceback:
#
# 1. lm(crim ~ zn)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = crim ~ zn, drop.unused.levels = TRUE)
# 5. model.frame.default(formula = crim ~ zn, drop.unused.levels = TRUE)
